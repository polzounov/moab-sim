# %% [markdown]
# # Imports and helpers

# %%
import os
import sys
import json
import time
import numpy as np
import matplotlib.pyplot as plt

from moabsim_old import MoabEnvOld
sys.path.append(os.getcwd() + '/../Baselines')
from moab_env import MoabEnv
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def uniform_circle(r):
    """Sample a point uniformly inside a circle with radius r."""
    angle = np.random.uniform(-np.pi, np.pi)

    # If we were to uniformly sample magnitude, points would be concentrated
    # more closer to the center, so we need to sample magnitudes scaled to
    # make everything evenly distributed
    unit_circle_mag = np.random.uniform(0, 1)
    unit_circle_mag = 1 - unit_circle_mag**2  # 1 - r^2
    mag = unit_circle_mag * r

    return mag * np.sin(angle), mag * np.cos(angle)

# %% [markdown]
# # Controllers

# %%
def pid_controller(
    Kp=75,  # Proportional coefficient
    Ki=0.5,  # Integral coefficient
    Kd=45,  # Derivative coefficient
    **kwargs
):
    sum_x, sum_y = 0, 0

    def next_action(x, y, vel_x, vel_y):
        nonlocal sum_x, sum_y
        sum_x += x
        sum_y += y

        action_x = Kp * x + Ki * sum_x + Kd * vel_x
        action_y = Kp * y + Ki * sum_y + Kd * vel_y

        action = np.array([-action_y, action_x])  # Match order of old sim

        # Use actions between -1 and +1 instead of degrees
        action /= -22
        pitch, roll = np.clip(action, -1, 1)

        return pitch, roll

    return next_action

# %% [markdown]
# # Comapre variations of old Moab sim and new Moab sim
# - With instant plate angles (new pitch and roll is whatever the NN sets it to)
# - With linear acceleration of the plate angles (don't instantly set new pitch and roll, let it take some time...)
# - Quantization of plate angles to nearest angle

# %%
# fmt: off
n = 2000

plate_radius = 0.1125
max_init_vel = 7.0
init_x, init_y = uniform_circle(plate_radius * 0.6)
init_x_vel, init_y_vel = uniform_circle(max_init_vel)

dt = 0.033 # in s == ~30Hz
config = {
    "initial_roll": 0.0,
    "initial_pitch": 0.0,
    "initial_x": init_x,
    "initial_y": init_y,
    "initial_vel_x": init_x_vel,
    "initial_vel_y": init_y_vel,
    "dt": dt,  # name in new sim
    "time_delta": dt,  # name in old sim
    "jitter": 0.004,  # in s, +/- 4ms
    "gravity": 9.81,  # m/s^2, Earth: there's no place like it.
    "plate_radius": 0.1125,  # m, Moab: 112.5mm radius
    "ball_mass": 0.0027,  # kg, Ping-Pong ball: 2.7g
    "ball_radius": 0.02,  # m, Ping-Pong ball: 20mm
    "ball_shell": 0.0002,  # m, Ping-Pong ball: 0.2
}

options = [
    # {"name": "(New) Instant Position", "env": MoabEnv, "config": config, "kwargs": {"linear_acceleration_servos": False, "quantize": False}},
    # {"name": "(Old) Instant Position", "env": MoabEnvOld, "config": config, "kwargs": {"linear_acceleration_servos": False, "quantize": False}},
    {"name": "(New) Linear Acceleration", "env": MoabEnv, "config": config, "kwargs": {"linear_acceleration_servos": True, "quantize": False}},
    {"name": "(New) Linear Acceleration 2", "env": MoabEnv, "config": config, "kwargs": {"linear_acceleration_servos": True, "quantize": False}},
    # {"name": "(Old) Linear Acceleration", "env": MoabEnvOld, "config": config, "kwargs": {"linear_acceleration_servos": True, "quantize": False}},
    # {"name": "(New) Quantized Angles", "env": MoabEnv, "config": config, "kwargs": {"linear_acceleration_servos": False, "quantize": True}},
    # {"name": "(Old) Quantized Angles", "env": MoabEnvOld, "config": config, "kwargs": {"linear_acceleration_servos": False, "quantize": True}},
    {"name": "(New) All mods (duplicated sim)", "env": MoabEnv, "config": config, "kwargs": {"linear_acceleration_servos": True, "quantize": True}},
    {"name": "(Old) All mods (original sim)", "env": MoabEnvOld, "config": config, "kwargs": {"linear_acceleration_servos": True, "quantize": True}},
]
state_hists = {}

for opt in options:
    # Run sim with specified options
    env = opt["env"](**opt["kwargs"])
    env.reset(config=opt["config"])
        
    state_hists[opt["name"]] = np.zeros((n, 6))
    controller = pid_controller()
    state = init_x, init_y, init_x_vel, init_y_vel

    t_start = time.time()
    for i in range(n):
        action = pitch, roll = controller(*state)
        state, info, _, _ = env.step(np.asarray(action))
        x, y, x_vel, y_vel = state
        state_hists[opt["name"]][i, :] = x, y, x_vel, y_vel, pitch, roll
    print(f"Time elapsed for {n} timesteps is {time.time() - t_start:.5f} seconds. Running: {opt['name']}")

# Ploty thingy
fig, axes = plt.subplots(3, 2, figsize=(20, 15))

for opt in options:
    axes[0][0].plot(np.arange(n), state_hists[opt["name"]][:, 0], label=opt["name"])
    axes[0][1].plot(np.arange(n), state_hists[opt["name"]][:, 1], label=opt["name"])
    axes[1][0].plot(np.arange(n), state_hists[opt["name"]][:, 2], label=opt["name"])
    axes[1][1].plot(np.arange(n), state_hists[opt["name"]][:, 3], label=opt["name"])
    axes[2][0].plot(np.arange(n), state_hists[opt["name"]][:, 4], label=opt["name"])
    axes[2][1].plot(np.arange(n), state_hists[opt["name"]][:, 5], label=opt["name"])

axes[0][0].set_title("X")
axes[0][0].legend()
axes[0][1].set_title("Y")
axes[0][1].legend()
axes[1][0].set_title("x_vel")
axes[1][0].legend()
axes[1][1].set_title("y_vel")
axes[1][1].legend()
axes[2][0].set_title("Pitch")
axes[2][0].legend()
axes[2][1].set_title("Roll")
axes[2][1].legend()

plt.show()
# fmt: on
# Out:
# Time elapsed for 2000 timesteps is 0.07067 seconds. Running: (New) Linear Acceleration
# Time elapsed for 2000 timesteps is 0.06457 seconds. Running: (New) Linear Acceleration 2
# Time elapsed for 2000 timesteps is 0.06348 seconds. Running: (New) All mods (duplicated sim)
# Time elapsed for 2000 timesteps is 1.16448 seconds. Running: (Old) All mods (original sim)
